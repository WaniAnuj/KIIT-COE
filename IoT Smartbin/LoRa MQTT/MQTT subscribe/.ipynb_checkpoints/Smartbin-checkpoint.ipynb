# %% [markdown]
# # MQTT subscribe

# %%
import paho.mqtt.client as mqtt

# The callback for when the client receives a CONNACK response from the server.
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected successfully")
    else:
        print("Connect returned result code: " + str(rc))

# The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
    print("Received message: " + msg.topic + " -> " + msg.payload.decode("utf-8"))

# create the client
client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message

# set username and password
client.username_pw_set("homonculus", "EYQTI21ANAUTK1YH")

# connect to HiveMQ Cloud on port 8883
client.connect("mqtt.thingspeak.com", 1883)

# subscribe to the topic "my/test/topic"
client.subscribe("channels/938535/subscribe/json/0OIREJZ69Q55B5YE")

# Blocking call that processes network traffic, dispatches callbacks and handles reconnecting.
client.loop_forever()

# %%
import thingspeak
ch = thingspeak.Channel(938535)
ch.get({'results': 1})
# ch.get()

# %% [markdown]
# # Thingspeak download using HTTP requests

# %%
import time
import requests
import json
# from pprint import pprint
# import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID = 938535
readAPIKey = "0OIREJZ69Q55B5YE"

lightList=[]
currentEntryID=0
secondsDelay=60


lora1=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID,readAPIKey))
# print("HTTP request report", r)
data=lora1.json()
lastUpdate = data["feeds"][0]["created_at"][-9:-1]
print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
print("Entry ID:", entryID)
longitude = data["feeds"][0]["field1"]
print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = data["feeds"][0]["field2"]
altitude = data["feeds"][0]["field3"]
humidity = data["feeds"][0]["field4"]
tempreture = data["feeds"][0]["field5"]
ppm = data["feeds"][0]["field6"]
pir = data["feeds"][0]["field7"]
dist = data["feeds"][0]["field8"]
hour=lastUpdate[-9:-1]
print("Time: ", hour)

# %% [markdown]
# # Plot

# %%
# %matplotlib inline
import time
import requests
import json
import matplotlib.pyplot as plt
# from pprint import pprint
# import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID = 938535
readAPIKey = "0OIREJZ69Q55B5YE"

currentEntryID=0
secondsDelay=60


lora1=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID,readAPIKey))
# print("HTTP request report", r)
data=lora1.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = data["feeds"][0]["field1"]
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = data["feeds"][0]["field2"]
altitude = data["feeds"][0]["field3"]
humidity = data["feeds"][0]["field4"]
tempreture = data["feeds"][0]["field5"]
ppm = data["feeds"][0]["field6"]
pir = data["feeds"][0]["field7"]
dist = data["feeds"][0]["field8"]
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

plt.figure(figsize = (10,20))
plt.subplot(4,2,1)
plt.scatter(hour,longitude, color = 'red', label = 'LoRa1')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Longitude')
plt.title('LONGITUDE')
# plt.axis([25,50,25,50])
plt.grid()
plt.legend()

plt.subplot(4,2,2)
plt.scatter(hour,latitude, color = 'red', label = 'LoRa1')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Latitude')
plt.title('LATITUDE')
# plt.axis([25,50,25,50])
plt.grid()

plt.subplot(4,2,3)
plt.scatter(hour,altitude, color = 'red')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Altitude')
plt.title('ALTITUDE')
# plt.axis([25,50,25,50])
plt.grid()

plt.subplot(4,2,4)
plt.scatter(hour,humidity, color = 'red')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Humidity(%)')
plt.title('HUMIDITY')
# plt.axis([25,50,25,50])
plt.grid()

plt.subplot(4,2,5)
plt.scatter(hour,tempreture, color = 'red')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Tempreture(deg cel)')
plt.title('TEMPRETURE')
# plt.axis([25,50,25,50])
plt.grid()

plt.subplot(4,2,6)
plt.scatter(hour,ppm, color = 'red')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('CO2 conc(ppm)')
plt.title('CO2 concentration')
# plt.axis([25,50,25,50])
plt.grid()

plt.subplot(4,2,7)
plt.scatter(hour,pir, color = 'red')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('PIR count')
plt.title('PIR COUNT')
# plt.axis([25,50,25,50])
plt.grid()

plt.subplot(4,2,8)
plt.scatter(hour,dist, color = 'red')
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Distance(cm)')
plt.title('DISTANCE')
# plt.axis([25,50,25,50])
plt.grid()

plt.show()
plt.close()

# %% [markdown]
# # Multichannel plot

# %%
# %matplotlib inline
import time
import requests
import json
import matplotlib.pyplot as plt
# from pprint import pprint
# import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora1 = 0
currentEntryID_gsm = 0
secondsDelay=60

plt.figure(figsize = (10,20))
plt.subplot(4,2,1)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Longitude')
plt.title('LONGITUDE')
plt.grid()

plt.subplot(4,2,2)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Latitude')
plt.title('LATITUDE')
plt.grid()

plt.subplot(4,2,3)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Altitude')
plt.title('ALTITUDE')
plt.grid()

plt.subplot(4,2,4)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Humidity(%)')
plt.title('HUMIDITY')
plt.grid()

plt.subplot(4,2,5)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Tempreture(deg cel)')
plt.title('TEMPRETURE')
plt.grid()

plt.subplot(4,2,6)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('CO2 conc(ppm)')
plt.title('CO2 concentration')
plt.grid()

plt.subplot(4,2,7)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('PIR count')
plt.title('PIR COUNT')
plt.grid()

plt.subplot(4,2,8)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Distance(cm)')
plt.title('DISTANCE')
plt.grid()


lora1=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
# print("HTTP request report", r)
data=lora1.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = data["feeds"][0]["field1"]
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = data["feeds"][0]["field2"]
altitude = data["feeds"][0]["field3"]
humidity = data["feeds"][0]["field4"]
tempreture = data["feeds"][0]["field5"]
ppm = data["feeds"][0]["field6"]
pir = data["feeds"][0]["field7"]
dist = data["feeds"][0]["field8"]
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

plt.subplot(4,2,1)
plt.scatter(hour,longitude, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,2)
plt.scatter(hour,latitude, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,3)
plt.scatter(hour,altitude, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,4)
plt.scatter(hour,humidity, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,5)
plt.scatter(hour,tempreture, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,6)
plt.scatter(hour,ppm, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,7)
plt.scatter(hour,pir, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()

plt.subplot(4,2,8)
plt.scatter(hour,dist, color = 'red', label = 'LoRa1')
# plt.grid()
plt.legend()


gsm=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_gsm,readAPIKey_gsm))
# print("HTTP request report", r)
data=gsm.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = data["feeds"][0]["field1"]
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = data["feeds"][0]["field2"]
altitude = data["feeds"][0]["field3"]
humidity = data["feeds"][0]["field4"]
tempreture = data["feeds"][0]["field5"]
ppm = data["feeds"][0]["field6"]
pir = data["feeds"][0]["field7"]
dist = data["feeds"][0]["field8"]
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

plt.subplot(4,2,1)
plt.scatter(hour,longitude, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,2)
plt.scatter(hour,latitude, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,3)
plt.scatter(hour,altitude, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,4)
plt.scatter(hour,humidity, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,5)
plt.scatter(hour,tempreture, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,6)
plt.scatter(hour,ppm, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,7)
plt.scatter(hour,pir, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.subplot(4,2,8)
plt.scatter(hour,dist, color = 'blue', label = 'GSM')
# plt.grid()
plt.legend()

plt.show()
plt.close()

# %% [markdown]
# # Fig, ax

# %%
# %matplotlib inline
import time
import requests
import json
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Subplot
# from pprint import pprint
# import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora1 = 0
currentEntryID_gsm = 0
secondsDelay=60

fig = plt.figure(figsize = (10,20))
# fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
ax1 = Subplot(fig, 421)
fig.add_subplot(ax1)
ax1.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Longitude', title = 'LONGITUDE')
ax1.grid(which = 'both')

ax2 = Subplot(fig, 422)
fig.add_subplot(ax2)
ax2.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Latitude', title = 'LATITUDE')
ax2.grid(True)

ax3 = Subplot(fig, 423)
fig.add_subplot(ax3)
ax3.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Altitude', title = 'ALTITUDE')
ax3.grid(True)

ax4 = Subplot(fig, 424)
fig.add_subplot(ax4)
ax4.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Humidity(%)', title = 'HUMIDITY')
ax4.grid(True)

ax5 = Subplot(fig, 425)
fig.add_subplot(ax5)
ax5.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Temperature (deg cel)', title = 'TEMPERATURE')
ax5.grid(True)

ax6 = Subplot(fig, 426)
fig.add_subplot(ax6)
ax6.set(xlabel = 'Time in hh:mm:ss', ylabel = 'CO2 conc(ppm)', title = 'CO2 concentration')
ax6.grid(True)

ax7 = Subplot(fig, 427)
fig.add_subplot(ax7)
ax7.set(xlabel = 'Time in hh:mm:ss', ylabel = 'PIR count', title = 'PIR COUNT')
ax7.grid(True)

ax8 = Subplot(fig, 428)
fig.add_subplot(ax8)
ax8.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Distance(cm)', title = 'DISTANCE')
ax8.grid(True)


lora1=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
# print("HTTP request report", r)
data=lora1.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = data["feeds"][0]["field1"]
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = data["feeds"][0]["field2"]
altitude = data["feeds"][0]["field3"]
humidity = data["feeds"][0]["field4"]
tempreture = data["feeds"][0]["field5"]
ppm = data["feeds"][0]["field6"]
pir = data["feeds"][0]["field7"]
dist = data["feeds"][0]["field8"]
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

# plt.subplot(4,2,1)
ax1.scatter(hour,longitude, color = 'red', label = 'LoRa1')
# plt.grid()
ax1.legend()

# plt.subplot(4,2,2)
ax2.scatter(hour,latitude, color = 'red', label = 'LoRa1')
# plt.grid()
ax2.legend()

# plt.subplot(4,2,3)
ax3.scatter(hour,altitude, color = 'red', label = 'LoRa1')
# plt.grid()
ax3.legend()

# plt.subplot(4,2,4)
ax4.scatter(hour,humidity, color = 'red', label = 'LoRa1')
# plt.grid()
ax4.legend()

# plt.subplot(4,2,5)
ax5.scatter(hour,tempreture, color = 'red', label = 'LoRa1')
# plt.grid()
ax5.legend()

# plt.subplot(4,2,6)
ax6.scatter(hour,ppm, color = 'red', label = 'LoRa1')
# plt.grid()
ax6.legend()

# plt.subplot(4,2,7)
ax7.scatter(hour,pir, color = 'red', label = 'LoRa1')
# plt.grid()
ax7.legend()

# plt.subplot(4,2,8)
ax8.scatter(hour,dist, color = 'red', label = 'LoRa1')
# plt.grid()
ax8.legend()


gsm=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_gsm,readAPIKey_gsm))
# print("HTTP request report", r)
data=gsm.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = data["feeds"][0]["field1"]
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = data["feeds"][0]["field2"]
altitude = data["feeds"][0]["field3"]
humidity = data["feeds"][0]["field4"]
tempreture = data["feeds"][0]["field5"]
ppm = data["feeds"][0]["field6"]
pir = data["feeds"][0]["field7"]
dist = data["feeds"][0]["field8"]
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

# plt.subplot(4,2,1)
ax1.scatter(hour,longitude, color = 'blue', label = 'GSM')
# plt.grid()
ax1.legend()

# plt.subplot(4,2,2)
ax2.scatter(hour,latitude, color = 'blue', label = 'GSM')
# plt.grid()
ax2.legend()

# plt.subplot(4,2,3)
ax3.scatter(hour,altitude, color = 'blue', label = 'GSM')
# plt.grid()
ax3.legend()

# plt.subplot(4,2,4)
ax4.scatter(hour,humidity, color = 'blue', label = 'GSM')
# plt.grid()
ax4.legend()

# plt.subplot(4,2,5)
ax5.scatter(hour,tempreture, color = 'blue', label = 'GSM')
# plt.grid()
ax5.legend()

# plt.subplot(4,2,6)
ax6.scatter(hour,ppm, color = 'blue', label = 'GSM')
# plt.grid()
ax6.legend()

# plt.subplot(4,2,7)
ax7.scatter(hour,pir, color = 'blue', label = 'GSM')
# plt.grid()
ax7.legend()

# plt.subplot(4,2,8)
ax8.scatter(hour,dist, color = 'blue', label = 'GSM')
# plt.grid()
ax8.legend()

plt.show()
plt.close()

# %% [markdown]
# # .plot

# %%
# %matplotlib inline
import time
import requests
import json
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Subplot
# from pprint import pprint
import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora1 = 0
currentEntryID_gsm = 0
secondsDelay=60

fig = plt.figure(figsize = (10,20))
# fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
ax1 = Subplot(fig, 421)
fig.add_subplot(ax1)
ax1.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Longitude', title = 'LONGITUDE')
ax1.grid(which = 'both')

ax2 = Subplot(fig, 422)
fig.add_subplot(ax2)
ax2.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Latitude', title = 'LATITUDE')
ax2.grid(True)

ax3 = Subplot(fig, 423)
fig.add_subplot(ax3)
ax3.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Altitude', title = 'ALTITUDE')
ax3.grid(True)

ax4 = Subplot(fig, 424)
fig.add_subplot(ax4)
ax4.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Humidity(%)', title = 'HUMIDITY')
ax4.grid(True)

ax5 = Subplot(fig, 425)
fig.add_subplot(ax5)
ax5.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Temperature (deg cel)', title = 'TEMPERATURE')
ax5.grid(True)

ax6 = Subplot(fig, 426)
fig.add_subplot(ax6)
ax6.set(xlabel = 'Time in hh:mm:ss', ylabel = 'CO2 conc(ppm)', title = 'CO2 concentration')
ax6.grid(True)

ax7 = Subplot(fig, 427)
fig.add_subplot(ax7)
ax7.set(xlabel = 'Time in hh:mm:ss', ylabel = 'PIR count', title = 'PIR COUNT')
ax7.grid(True)

ax8 = Subplot(fig, 428)
fig.add_subplot(ax8)
ax8.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Distance(cm)', title = 'DISTANCE')
ax8.grid(True)


lora1=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
# print("HTTP request report", r)
data=lora1.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = float(data["feeds"][0]["field1"])
print(type(longitude))
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = float(data["feeds"][0]["field2"])
altitude = float(data["feeds"][0]["field3"])
humidity = float(data["feeds"][0]["field4"])
tempreture = float(data["feeds"][0]["field5"])
ppm = float(data["feeds"][0]["field6"])
pir = float(data["feeds"][0]["field7"])
dist = float(data["feeds"][0]["field8"])
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

# plt.subplot(4,2,1)
ax1.plot(hour,longitude, color = 'red', label = 'LoRa1')
# plt.grid()
ax1.legend()

# plt.subplot(4,2,2)
ax2.plot(hour,latitude, color = 'red', label = 'LoRa1')
# plt.grid()
ax2.legend()

# plt.subplot(4,2,3)
ax3.plot(hour,altitude, color = 'red', label = 'LoRa1')
# plt.grid()
ax3.legend()

# plt.subplot(4,2,4)
ax4.plot(hour,humidity, color = 'red', label = 'LoRa1')
# plt.grid()
ax4.legend()

# plt.subplot(4,2,5)
ax5.plot(hour,tempreture, color = 'red', label = 'LoRa1')
# plt.grid()
ax5.legend()

# plt.subplot(4,2,6)
ax6.plot(hour,ppm, color = 'red', label = 'LoRa1')
# plt.grid()
ax6.legend()

# plt.subplot(4,2,7)
ax7.plot(hour,pir, color = 'red', label = 'LoRa1')
# plt.grid()
ax7.legend()

# plt.subplot(4,2,8)
ax8.plot(hour,dist, color = 'red', label = 'LoRa1')
# plt.grid()
ax8.legend()


gsm=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_gsm,readAPIKey_gsm))
# print("HTTP request report", r)
data=gsm.json()
lastUpdate = data["feeds"][0]["created_at"]
# print("Last updated:", lastUpdate)
entryID = data["feeds"][0]["entry_id"]
# print("Entry ID:", entryID)
longitude = float(data["feeds"][0]["field1"])
# print("LORA1 \n Longitude: {0}\n Latitiude: {1}\n Altitude: {2}\n Humidity: {3}\n Tempreture: {4}\n CO2 conc: {5}\n PIR: {6}\n Distance: {7}\n ".format(longitude,latitude,altitude,humidity,tempreture,ppm,pir,dist))
latitude = float(data["feeds"][0]["field2"])
altitude = float(data["feeds"][0]["field3"])
humidity = float(data["feeds"][0]["field4"])
tempreture = float(data["feeds"][0]["field5"])
ppm = float(data["feeds"][0]["field6"])
pir = float(data["feeds"][0]["field7"])
dist = float(data["feeds"][0]["field8"])
hour=lastUpdate[-9:-1]
# print("Time: ", hour)

# plt.subplot(4,2,1)
ax1.plot(hour,longitude, color = 'blue', label = 'GSM')
# plt.grid()
ax1.legend()

# plt.subplot(4,2,2)
ax2.plot(hour,latitude, color = 'blue', label = 'GSM')
# plt.grid()
ax2.legend()

# plt.subplot(4,2,3)
ax3.plot(hour,altitude, color = 'blue', label = 'GSM')
# plt.grid()
ax3.legend()

# plt.subplot(4,2,4)
ax4.plot(hour,humidity, color = 'blue', label = 'GSM')
# plt.grid()
ax4.legend()

# plt.subplot(4,2,5)
ax5.plot(hour,tempreture, color = 'blue', label = 'GSM')
# plt.grid()
ax5.legend()

# plt.subplot(4,2,6)
ax6.plot(hour,ppm, color = 'blue', label = 'GSM')
# plt.grid()
ax6.legend()

# plt.subplot(4,2,7)
ax7.plot(hour,pir, color = 'blue', label = 'GSM')
# plt.grid()
ax7.legend()

# plt.subplot(4,2,8)
ax8.plot(hour,dist, color = 'blue', label = 'GSM')
# plt.grid()
ax8.legend()

plt.show()
plt.close()

# %%
import datetime
x= datetime.datetime.now()
hour = int(x.strftime("%H"))
print(x)
print(hour)

# %% [markdown]
# # DF fig,ax only shows 1st subplots

# %%
# %matplotlib inline
import pandas as pd
import time
import requests
import json
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Subplot
# from pprint import pprint
import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora = 0
currentEntryID_gsm = 0
secondsDelay=60
loracount = 0
gsmcount = 0

fig = plt.figure(figsize = (10,20))
# fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
ax1 = Subplot(fig, 421)
fig.add_subplot(ax1)
ax1.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Longitude', title = 'LONGITUDE')
ax1.grid(which = 'both')

ax2 = Subplot(fig, 422)
fig.add_subplot(ax2)
ax2.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Latitude', title = 'LATITUDE')
ax2.grid(True)

ax3 = Subplot(fig, 423)
fig.add_subplot(ax3)
ax3.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Altitude', title = 'ALTITUDE')
ax3.grid(True)

ax4 = Subplot(fig, 424)
fig.add_subplot(ax4)
ax4.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Humidity(%)', title = 'HUMIDITY')
ax4.grid(True)

ax5 = Subplot(fig, 425)
fig.add_subplot(ax5)
ax5.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Temperature (deg cel)', title = 'TEMPERATURE')
ax5.grid(True)

ax6 = Subplot(fig, 426)
fig.add_subplot(ax6)
ax6.set(xlabel = 'Time in hh:mm:ss', ylabel = 'CO2 conc(ppm)', title = 'CO2 concentration')
ax6.grid(True)

ax7 = Subplot(fig, 427)
fig.add_subplot(ax7)
ax7.set(xlabel = 'Time in hh:mm:ss', ylabel = 'PIR count', title = 'PIR COUNT')
ax7.grid(True)

ax8 = Subplot(fig, 428)
fig.add_subplot(ax8)
ax8.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Distance(cm)', title = 'DISTANCE')
ax8.grid(True)

while(True):
    loraresp=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
    # print("HTTP request report", r)
    loradata=loraresp.json()
    loraentryID = float(loradata["feeds"][0]["entry_id"])
    if currentEntryID_lora != loraentryID:
        currentEntryID_lora = loraentryID
        if loracount == 0:
            lora = {'entryid':[loradata["feeds"][0]["entry_id"]],'time':[loradata["feeds"][0]["created_at"][-9:-1]],'longitude':[float(loradata["feeds"][0]["field1"])],'latitude':[float(loradata["feeds"][0]["field2"])],'altitude':[float(loradata["feeds"][0]["field3"])],'humidity':[float(loradata["feeds"][0]["field4"])],'temperature':[float(loradata["feeds"][0]["field5"])],'co2':[float(loradata["feeds"][0]["field6"])],'pir':[float(loradata["feeds"][0]["field7"])],'distance':[float(loradata["feeds"][0]["field8"])]}
            loradf = pd.DataFrame(data = lora)
            print(loradf)
        else:
            if len(loradf) == 10:
                loradf.drop(0, axis=0, inplace=True)
                idx = range(loracount)
                loradf.index = idx
#                 print(lora1)
#                 print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
#                 print(lora1df)
                print("*************************************************")
            else:
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
                print(loradf)
                
        ax1.plot(loradf['time'],loradf['longitude'], 'ro', label = 'LoRa1')
        ax1.legend()

        ax2.plot(loradf['time'],loradf['latitude'], 'ro', label = 'LoRa1')
        ax2.legend()

        ax3.plot(loradf['time'],loradf['altitude'], 'ro', label = 'LoRa1')
        ax3.legend()

        ax4.plot(loradf['time'],loradf['humidity'], 'ro', label = 'LoRa1')
        ax4.legend()

        ax5.plot(loradf['time'],loradf['temperature'], 'ro', label = 'LoRa1')
        ax5.legend()

        ax6.plot(loradf['time'],loradf['co2'],'ro', label = 'LoRa1')
        ax6.legend()

        ax7.plot(loradf['time'],loradf['pir'], 'ro', label = 'LoRa1')
        ax7.legend()

        ax8.plot(loradf['time'],loradf['distance'], 'ro', label = 'LoRa1')
        ax8.legend()
        
        plt.show()
        plt.close()
        
        if loracount != 9:
            loracount+=1
        else:
            loracount = 9   
            
        
        time.sleep(30)

# %% [markdown]
# # DF plt updates and shows subplots but figsize messed up after 1st subplot

# %%
# %matplotlib inline
import pandas as pd
import time
import requests
import json
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Subplot
# from pprint import pprint
import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora = 0
currentEntryID_gsm = 0
secondsDelay=60
loracount = 0
gsmcount = 0

plt.figure(figsize = (10,20))
plt.subplot(4,2,1)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Longitude')
plt.title('LONGITUDE')
plt.grid()

plt.subplot(4,2,2)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Latitude')
plt.title('LATITUDE')
plt.grid()

plt.subplot(4,2,3)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Altitude')
plt.title('ALTITUDE')
plt.grid()

plt.subplot(4,2,4)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Humidity(%)')
plt.title('HUMIDITY')
plt.grid()

plt.subplot(4,2,5)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Tempreture(deg cel)')
plt.title('TEMPRETURE')
plt.grid()

plt.subplot(4,2,6)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('CO2 conc(ppm)')
plt.title('CO2 concentration')
plt.grid()

plt.subplot(4,2,7)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('PIR count')
plt.title('PIR COUNT')
plt.grid()

plt.subplot(4,2,8)
plt.xlabel('Time in hh:mm:ss')
plt.ylabel('Distance(cm)')
plt.title('DISTANCE')
plt.grid()


while(True):
    loraresp=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
    # print("HTTP request report", r)
    loradata=loraresp.json()
    loraentryID = float(loradata["feeds"][0]["entry_id"])
    if currentEntryID_lora != loraentryID:
        currentEntryID_lora = loraentryID
        if loracount == 0:
            lora = {'entryid':[loradata["feeds"][0]["entry_id"]],'time':[loradata["feeds"][0]["created_at"][-9:-1]],'longitude':[float(loradata["feeds"][0]["field1"])],'latitude':[float(loradata["feeds"][0]["field2"])],'altitude':[float(loradata["feeds"][0]["field3"])],'humidity':[float(loradata["feeds"][0]["field4"])],'temperature':[float(loradata["feeds"][0]["field5"])],'co2':[float(loradata["feeds"][0]["field6"])],'pir':[float(loradata["feeds"][0]["field7"])],'distance':[float(loradata["feeds"][0]["field8"])]}
            loradf = pd.DataFrame(data = lora)
            print(loradf)
        else:
            if len(loradf) == 10:
                loradf.drop(0, axis=0, inplace=True)
                idx = range(loracount)
                loradf.index = idx
#                 print(lora1)
#                 print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
#                 print(lora1df)
                print("*************************************************")
            else:
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
                print(loradf)
        
        plt.subplot(4,2,1)
        plt.plot(loradf['time'],loradf['longitude'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,2)
        plt.plot(loradf['time'],loradf['latitude'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,3)
        plt.plot(loradf['time'],loradf['altitude'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,4)
        plt.plot(loradf['time'],loradf['humidity'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,5)
        plt.plot(loradf['time'],loradf['temperature'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,6)
        plt.plot(loradf['time'],loradf['co2'],'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,7)
        plt.plot(loradf['time'],loradf['pir'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

        plt.subplot(4,2,8)
        plt.plot(loradf['time'],loradf['distance'], 'ro-', label = 'LoRa1')
        # plt.grid()
        plt.legend()

#         ax1.plot(loradf['time'],loradf['longitude'], 'ro', label = 'LoRa1')
#         ax1.legend()

#         ax2.plot(loradf['time'],loradf['latitude'], 'ro', label = 'LoRa1')
#         ax2.legend()

#         ax3.plot(loradf['time'],loradf['altitude'], 'ro', label = 'LoRa1')
#         ax3.legend()

#         ax4.plot(loradf['time'],loradf['humidity'], 'ro', label = 'LoRa1')
#         ax4.legend()

#         ax5.plot(loradf['time'],loradf['temperature'], 'ro', label = 'LoRa1')
#         ax5.legend()

#         ax6.plot(loradf['time'],loradf['co2'],'ro', label = 'LoRa1')
#         ax6.legend()

#         ax7.plot(loradf['time'],loradf['pir'], 'ro', label = 'LoRa1')
#         ax7.legend()

#         ax8.plot(loradf['time'],loradf['distance'], 'ro', label = 'LoRa1')
#         ax8.legend()
        
        plt.show()
        plt.close()
        
        if loracount != 9:
            loracount+=1
        else:
            loracount = 9   
            
        
        time.sleep(30)

# %% [markdown]
# # DF animation fig,ax only shows 1st subplots

# %%
# %matplotlib inline
import pandas as pd
import time
import requests
import json
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Subplot
import matplotlib.animation as animation
# from pprint import pprint
import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora = 0
currentEntryID_gsm = 0
secondsDelay=60
loracount = 0
gsmcount = 0

fig = plt.figure(figsize = (10,20))
# fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
ax1 = Subplot(fig, 421)
fig.add_subplot(ax1)
ax1.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Longitude', title = 'LONGITUDE')
ax1.grid(which = 'both')

ax2 = Subplot(fig, 422)
fig.add_subplot(ax2)
ax2.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Latitude', title = 'LATITUDE')
ax2.grid(True)

ax3 = Subplot(fig, 423)
fig.add_subplot(ax3)
ax3.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Altitude', title = 'ALTITUDE')
ax3.grid(True)

ax4 = Subplot(fig, 424)
fig.add_subplot(ax4)
ax4.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Humidity(%)', title = 'HUMIDITY')
ax4.grid(True)

ax5 = Subplot(fig, 425)
fig.add_subplot(ax5)
ax5.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Temperature (deg cel)', title = 'TEMPERATURE')
ax5.grid(True)

ax6 = Subplot(fig, 426)
fig.add_subplot(ax6)
ax6.set(xlabel = 'Time in hh:mm:ss', ylabel = 'CO2 conc(ppm)', title = 'CO2 concentration')
ax6.grid(True)

ax7 = Subplot(fig, 427)
fig.add_subplot(ax7)
ax7.set(xlabel = 'Time in hh:mm:ss', ylabel = 'PIR count', title = 'PIR COUNT')
ax7.grid(True)

ax8 = Subplot(fig, 428)
fig.add_subplot(ax8)
ax8.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Distance(cm)', title = 'DISTANCE')
ax8.grid(True)

while(True):
    loraresp=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
    # print("HTTP request report", r)
    loradata=loraresp.json()
    loraentryID = float(loradata["feeds"][0]["entry_id"])
    if currentEntryID_lora != loraentryID:
        currentEntryID_lora = loraentryID
        if loracount == 0:
            lora = {'entryid':[loradata["feeds"][0]["entry_id"]],'time':[loradata["feeds"][0]["created_at"][-9:-1]],'longitude':[float(loradata["feeds"][0]["field1"])],'latitude':[float(loradata["feeds"][0]["field2"])],'altitude':[float(loradata["feeds"][0]["field3"])],'humidity':[float(loradata["feeds"][0]["field4"])],'temperature':[float(loradata["feeds"][0]["field5"])],'co2':[float(loradata["feeds"][0]["field6"])],'pir':[float(loradata["feeds"][0]["field7"])],'distance':[float(loradata["feeds"][0]["field8"])]}
            loradf = pd.DataFrame(data = lora)
            print(loradf)
        else:
            if len(loradf) == 10:
                loradf.drop(0, axis=0, inplace=True)
                idx = range(loracount)
                loradf.index = idx
#                 print(lora1)
#                 print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
#                 print(lora1df)
                print("*************************************************")
            else:
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
                print(loradf)
        animation.FuncAnimation(fig, ax1.plot(loradf['time'],loradf['longitude'], 'ro', label = 'LoRa1'), interval=1000)        
#         ax1.plot(loradf['time'],loradf['longitude'], 'ro', label = 'LoRa1')
        ax1.legend()

        animation.FuncAnimation(fig, ax2.plot(loradf['time'],loradf['latitude'], 'ro', label = 'LoRa1'), interval=1000)
#         ax2.plot(loradf['time'],loradf['latitude'], 'ro', label = 'LoRa1')
        ax2.legend()
        
        animation.FuncAnimation(fig, ax3.plot(loradf['time'],loradf['altitude'], 'ro', label = 'LoRa1'), interval=1000)
#         ax3.plot(loradf['time'],loradf['altitude'], 'ro', label = 'LoRa1')
        ax3.legend()

        animation.FuncAnimation(fig, ax4.plot(loradf['time'],loradf['humidity'], 'ro', label = 'LoRa1'), interval=1000)
#         ax4.plot(loradf['time'],loradf['humidity'], 'ro', label = 'LoRa1')
        ax4.legend()
        
        animation.FuncAnimation(fig, ax5.plot(loradf['time'],loradf['temperature'], 'ro', label = 'LoRa1'), interval=1000)
#         ax5.plot(loradf['time'],loradf['temperature'], 'ro', label = 'LoRa1')
        ax5.legend()

        animation.FuncAnimation(fig, ax6.plot(loradf['time'],loradf['co2'],'ro', label = 'LoRa1'), interval=1000)
#         ax6.plot(loradf['time'],loradf['co2'],'ro', label = 'LoRa1')
        ax6.legend()

        animation.FuncAnimation(fig, ax7.plot(loradf['time'],loradf['pir'], 'ro', label = 'LoRa1'), interval=1000)
#         ax7.plot(loradf['time'],loradf['pir'], 'ro', label = 'LoRa1')
        ax7.legend()

        animation.FuncAnimation(fig, ax8.plot(loradf['time'],loradf['distance'], 'ro', label = 'LoRa1'), interval=1000)
#         ax8.plot(loradf['time'],loradf['distance'], 'ro', label = 'LoRa1')
        ax8.legend()
        
        plt.show()
#         plt.close()
        
        if loracount != 9:
            loracount+=1
        else:
            loracount = 9   
            
        
        time.sleep(30)

# %%
# %matplotlib inline
import pandas as pd
import time
import requests
import json
import matplotlib.pyplot as plt
from mpl_toolkits.axisartist.axislines import Subplot
# from pprint import pprint
import datetime

# define channelID, readAPIKey, tweetAPIKey
channelID_lora1 = 938535
readAPIKey_lora1 = "0OIREJZ69Q55B5YE"
channelID_gsm = 668447
readAPIKey_gsm = "1NVIXUKIHQ8X6TDZ"

currentEntryID_lora = 0
currentEntryID_gsm = 0
secondsDelay=60
loracount = 0
gsmcount = 0



while(True):
    fig = plt.figure(figsize = (10,20))
    # fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6),(ax7,ax8)) = plt.subplots(4,2)
    ax1 = plt.subplot(4,2,1)
    ax1.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Longitude', title = 'LONGITUDE')
    ax1.grid(True)

    ax2 = plt.subplot(4,2,2)
    ax2.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Latitude', title = 'LATITUDE')
    ax2.grid(True)

    ax3 = plt.subplot(4,2,3)
    ax3.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Altitude', title = 'ALTITUDE')
    ax3.grid(True)

    ax4 = plt.subplot(4,2,4)
    ax4.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Humidity(%)', title = 'HUMIDITY')
    ax4.grid(True)

    ax5 = plt.subplot(4,2,5)
    ax5.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Temperature (deg cel)', title = 'TEMPERATURE')
    ax5.grid(True)

    ax6 = plt.subplot(4,2,6)
    ax6.set(xlabel = 'Time in hh:mm:ss', ylabel = 'CO2 conc(ppm)', title = 'CO2 concentration')
    ax6.grid(True)

    ax7 = plt.subplot(4,2,7)
    ax7.set(xlabel = 'Time in hh:mm:ss', ylabel = 'PIR count', title = 'PIR COUNT')
    ax7.grid(True)

    ax8 = plt.subplot(4,2,8)
    ax8.set(xlabel = 'Time in hh:mm:ss', ylabel = 'Distance(cm)', title = 'DISTANCE')
    ax8.grid(True)
    loraresp=requests.get("https://api.thingspeak.com/channels/%d/feeds.json?api_key=%s&results=1"%(channelID_lora1,readAPIKey_lora1))
    # print("HTTP request report", r)
    loradata=loraresp.json()
    loraentryID = float(loradata["feeds"][0]["entry_id"])
    if currentEntryID_lora != loraentryID:
        currentEntryID_lora = loraentryID
        if loracount == 0:
            lora = {'entryid':[loradata["feeds"][0]["entry_id"]],'time':[loradata["feeds"][0]["created_at"][-9:-1]],'longitude':[float(loradata["feeds"][0]["field1"])],'latitude':[float(loradata["feeds"][0]["field2"])],'altitude':[float(loradata["feeds"][0]["field3"])],'humidity':[float(loradata["feeds"][0]["field4"])],'temperature':[float(loradata["feeds"][0]["field5"])],'co2':[float(loradata["feeds"][0]["field6"])],'pir':[float(loradata["feeds"][0]["field7"])],'distance':[float(loradata["feeds"][0]["field8"])]}
            loradf = pd.DataFrame(data = lora)
            print(loradf)
        else:
            if len(loradf) == 10:
                loradf.drop(0, axis=0, inplace=True)
                idx = range(loracount)
                loradf.index = idx
#                 print(lora1)
#                 print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
#                 print(lora1df)
                print("*************************************************")
            else:
                loradf.loc[loracount] = [loradata["feeds"][0]["entry_id"],loradata["feeds"][0]["created_at"][-9:-1],float(loradata["feeds"][0]["field1"]),float(loradata["feeds"][0]["field2"]),float(loradata["feeds"][0]["field3"]),float(loradata["feeds"][0]["field4"]),float(loradata["feeds"][0]["field5"]),float(loradata["feeds"][0]["field6"]),float(loradata["feeds"][0]["field7"]),float(loradata["feeds"][0]["field8"])]
                print(loradf)
                
        ax1.plot(loradf['time'],loradf['longitude'], 'ro', label = 'LoRa1')
        ax1.legend()

        ax2.plot(loradf['time'],loradf['latitude'], 'ro', label = 'LoRa1')
        ax2.legend()

        ax3.plot(loradf['time'],loradf['altitude'], 'ro', label = 'LoRa1')
        ax3.legend()

        ax4.plot(loradf['time'],loradf['humidity'], 'ro', label = 'LoRa1')
        ax4.legend()

        ax5.plot(loradf['time'],loradf['temperature'], 'ro', label = 'LoRa1')
        ax5.legend()

        ax6.plot(loradf['time'],loradf['co2'],'ro', label = 'LoRa1')
        ax6.legend()

        ax7.plot(loradf['time'],loradf['pir'], 'ro', label = 'LoRa1')
        ax7.legend()

        ax8.plot(loradf['time'],loradf['distance'], 'ro', label = 'LoRa1')
        ax8.legend()
        
        plt.show()
        plt.close()
#         plt.draw()
#         plt.pause(0.5)
#         plt.show()
#         plt.cla()
#         plt.clf()
#         fig.clear()
        
        if loracount != 9:
            loracount+=1
        else:
            loracount = 9   
            
        
        time.sleep(30)
# Out:
# <ipython-input-3-da3df2e192e6>:26: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (10,20))
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ...
